# %% [markdown]
# <a href="https://colab.research.google.com/github/Maja-GHub/Copilot/blob/main/quickstarts/Get_started_interactions_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New section
